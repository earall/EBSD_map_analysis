# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

"""  Code to take import from rapid import function
and display ebsd data mapped into phases  """
# Out:
# '  Code to take import from rapid import function\nand display ebsd data mapped into phases  '

# %%
import functions

# %%
data, hdr = functions.rapid_func('AL001MeltsNR.ctf')
# Out:
# running phase key...
# [['1' 'Augite']
#  ['2' 'An38']
#  ['3' 'An67']
#  ['4' 'K_Feldspar']
#  ['5' 'Quartz-new']
#  ['6' 'Titanite']
#  ['7' 'An85']
#  ['8' 'Scapolite']
#  ['9' 'Clinozoisite']]
# *******************
# running results...
# 9
# 23.0
# [0.0, 0.0, 4.0, 4.0]
# [0.0, 15.556, 31.111, 46.667]
# [0.0, 0.0, 0.0, 0.0]
# 941814

# %%
# Take data input and split into named columns
P, X, Y = data.T

# %%
# Reshape function to initial shape of ebsd image
PR = P.reshape(963,978)
XR = X.reshape(963,978)
YR = Y.reshape(963,978)

# %%
# Plotting to colormesh according phase identifier 
plt.pcolormesh(XR, YR, PR)
plt.show()

# %%
import pandas
 
# Load the data into a DataFrame

dataT.groupby(P)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-53e8ec305d5e> in <module>()
#       3 # Load the data into a DataFrame
#       4
# ----> 5 dataT.groupby(P)
#
# NameError: name 'dataT' is not defined
